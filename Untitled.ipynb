# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import set_matplotlib_formats
import cufflinks as cf
import plotly.express as px

# %%
diamonds=pd.read_csv("/Users/luisdemiguel/Desktop/Ironhack/ih_datamadpt0420_project_m2/data/diamonds_train.csv")

# %%
#Interesting facts about diamonds:
    # 1. x=width
    # 2. y=lenght
    # 3. z=depth
    # 4. x+y=average diameter (this will give you the shape)
    # 5. average diameter/depth= total depth (here just depth) % of a diamond
    # 6. table = its the % of width of the table/total width

# %%
diamonds.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   1.21    Premium     J     VS2   62.4   58.0   4268  6.83  6.79  4.25
# 1   0.32  Very Good     H     VS2   63.0   57.0    505  4.35  4.38  2.75
# 2   0.71       Fair     G     VS1   65.5   55.0   2686  5.62  5.53  3.65
# 3   0.41       Good     D     SI1   63.8   56.0    738  4.68  4.72  3.00
# 4   1.02      Ideal     G     SI1   60.5   59.0   4882  6.55  6.51  3.95

# %%
diamonds['shape'] = diamonds['y']/diamonds['x']

# %%
shape = diamonds['shape'].tolist()

# %%
rounds = []
marquise = []
oval = []
heart = []
good = []
not_good_excellent = []


for i in shape:
    if 1.05 <= i < 1.15:
        rounds.append(i)
    elif 1.7 <= i < 2.30:
        marquise.append(i)
    elif 1.3 <= i < 1.7:
        oval.append(i)
    elif 1.15 <= i < 1.3:
        heart.append(i)
    elif 1.005 <= i < 1.05:
        good.append(i)
    else:
        not_gooexcellent.append(i)

print (not_excellent)
# Out:
# [0.9941434846266471, 1.006896551724138, 0.9839857651245552, 1.0085470085470085, 0.9938931297709923, 0.9919463087248321, 0.9935794542536116, 1.0040983606557377, 1.0092378752886837, 1.0059612518628913, 0.9918032786885246, 0.9649122807017544, 1.0032258064516129, 0.9959893048128342, 1.0052770448548813, 0.9946879150066401, 1.0041237113402062, 0.997854077253219, 1.0032894736842104, 0.9946308724832215, 0.9946380697050938, 0.992970123022847, 1.0093240093240092, 1.0042674253200568, 0.9906542056074766, 0.993798449612403, 0.9953775038520801, 0.9886363636363635, 0.9945578231292517, 0.9922600619195047, 0.9940476190476191, 1.0066666666666668, 1.0125, 1.0043859649122808, 1.0053097345132742, 0.9915682967959528, 0.9950799507995078, 0.9841549295774649, 0.9938176197836167, 0.9921104536489151, 1.005859375, 0.9878234398782344, 1.0054249547920433, 1.0050420168067227, 1.0070093457943923, 1.0065075921908893, 1.0092378752886837, 0.9925261584454409, 0.9915824915824915, 1.0061823802163834, 0.9930675909878685, 1.014519056261343, 1.0068649885583525, 1.0058252427184464, 0.9954751131221721, 0.9907192575406032, 0.988817891373802, 0.9931662870159454, 0.9899799599198397, 1.0053050397877985, 0.9936708860759493, 0.9955357142857142, 1.006880733944954, 1.0051546391752577, 0.9954751131221721, 0.9954545454545456, 0.9915254237288135, 0.9930875576036866, 1.0042796005706134, 1.003853564547206, 1.007462686567164, 1.0073421439060206, 0.9930675909878685, 1.0066137566137567, 1.0065359477124183, 1.009
# std         0.475544    NaN    NaN     NaN      1.431725      2.233535
# min         0.200000    NaN    NaN     NaN     43.000000     43.000000
# 25%         0.400000    NaN    NaN     NaN     61.000000     56.000000
# 50%         0.700000    NaN    NaN     NaN     61.800000     57.000000
# 75%         1.040000    NaN    NaN     NaN     62.500000     59.000000
# max         4.500000    NaN    NaN     NaN     79.000000     95.000000
#
#                price             x             y             z
# count   40455.000000  40455.000000  40455.000000  40455.000000
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean     3928.444469      5.729392      5.732819      3.537154
# std      3992.416147      1.124453      1.146650      0.697062
# min       326.000000      0.000000      0.000000      0.000000
# 25%       945.000000      4.710000      4.720000      2.910000
# 50%      2397.000000      5.690000      5.710000      3.520000
# 75%      5331.000000      6.540000      6.540000      4.035000
# max     18823.000000     10.230000     58.900000      8.060000

# %%
set_matplotlib_formats('svg')

# %matplotlib inline

# %%
# A first look and feel of the data
diamonds.hist(figsize=(12, 8), bins=20);

# %%
#a closer look at the price
#we can see that most of them go from 1k to 5k
#we can also see that the distribution after 12k its marginal, hence seems like its rare and unique to find diamonds with more than 12k price. Up to 18.8k (the max)

diamonds[['price']].clip(0, 15000).plot(kind='box', figsize=(8, 8))

# %%
diamonds[['carat']].clip(0, 400).plot(kind='box', figsize=(8, 8))

# %%
#i chose this kind of barplot for items like colors, clarity or cut with few options.
#we can see for example that the spread in clarity is notorious, from less than 1k for L1 to around 10k in SL1 
diamonds['clarity'].value_counts().plot.bar();

# %%
#we can see for example that the spread in cut is large as well, from less than 1k for "fair" to around 16k in "ideal" 
diamonds['cut'].value_counts().plot.bar();

# %%
diamonds['color'].value_counts().plot.bar();

# %%
#Here we can see based on the cut and the color, the distribution of prices.
#Being the premium and "I" and "J" color the most expensive ones.
fig = plt.figure(figsize=(15, 10))
ax = sns.barplot(x='color', y='price', hue='cut', data=diamonds)

# %%
#Together with the previous chart, we can observe:
#1. in terms of "cut", that the premium is the most expensive but the 2nd in terms of count.
    #this means that they rather produce or make premium cut. Seems like is worth the revenue compared to other "cut" options
#2. in terms of "color", being "J" and "I" the ones with less count but at the same time with the highest average in price, most probably because of being uniques

# %%
#diamonds['price'].iplot(kind='hist', title='price', yTitle='price', xTitle='carat', bins=100)
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-32-8743787a1d3e> in <module>
# ----> 1 diamonds['price'].iplot(kind='hist', title='price', yTitle='price', xTitle='carat', bins=100)
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/cufflinks/plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#    1216 		return iplot(figure,validate=validate,sharing=sharing,filename=filename,
#    1217                          online=online,asImage=asImage,asUrl=asUrl,asPlot=asPlot,
# -> 1218 			 dimensions=dimensions,display_image=kwargs.get('display_image',True))
#    1219
#    1220
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/cufflinks/plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1469         else:
#    1470 		return py.iplot(figure,validate=validate,sharing=sharing,
# -> 1471 						filename=filename)
#    1472
#    1473
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/plotly/plotly.py in iplot(figure_or_data, **plot_options)
#     133     if "auto_open" not in plot_options:
#     134         plot_options["auto_open"] = False
# --> 135     url = plot(figure_or_data, **plot_options)
#     136
#     137     if isinstance(figure_or_data, dict):
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/plotly/plotly.py in plot(figure_or_data, validate, **plot_options)
#     278             filename=grid_filename,
#     279             world_readable=payload["world_readable"],
# --> 280             auto_open=False,
#     281         )
#     282
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/plotly/plotly.py in upload(cls, grid, filename, world_readable, auto_open, meta)
#    1085                 payload["parent_path"] = parent_path
#    1086
# -> 1087         file_info = _create_or_overwrite_grid(payload)
#    1088
#    1089         cols = file_info["cols"]
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/plotly/plotly.py in _create_or_overwrite_grid(data, max_retries)
#    1548     # Create file
#    1549     try:
# -> 1550         res = api_module.create(data)
#    1551     except exceptions.PlotlyRequestError as e:
#    1552         if max_retries > 0 and "already exists" in e.message:
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/api/v2/grids.py in create(body)
#      16     """
#      17     url = build_url(RESOURCE)
# ---> 18     return request("post", url, json=body)
#      19
#      20
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/retrying.py in wrapped_f(*args, **kw)
#      47             @six.wraps(f)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#      51             return wrapped_f
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     204
#     205             if not self.should_reject(attempt):
# --> 206                 return attempt.get(self._wrap_exception)
#     207
#     208             delay_since_first_attempt_ms = int(round(time.time() * 1000)) - start_time
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/retrying.py in get(self, wrap_exception)
#     245                 raise RetryError(self)
#     246             else:
# --> 247                 six.reraise(self.value[0], self.value[1], self.value[2])
#     248         else:
#     249             return self.value
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/retrying.py in call(self, fn, *args, **kwargs)
#     198         while True:
#     199             try:
# --> 200                 attempt = Attempt(fn(*args, **kwargs), attempt_number, False)
#     201             except:
#     202                 tb = sys.exc_info()
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/api/v2/utils.py in request(method, url, **kwargs)
#     178         content = response.content if response else "No content"
#     179         raise exceptions.PlotlyRequestError(message, status_code, content)
# --> 180     validate_response(response)
#     181     return response
#
# ~/miniconda3/envs/ihm1_env/lib/python3.7/site-packages/chart_studio/api/v2/utils.py in validate_response(response)
#      80         message = content if content else "No Content"
#      81
# ---> 82     raise exceptions.PlotlyRequestError(message, status_code, content)
#      83
#      84
#
# PlotlyRequestError: Authentication credentials were not provided.

# %%
px.histogram(data_frame=diamonds, 
             x='price', 
             color='cut', 
             histnorm='percent', 
             barmode='overlay',
             title='prices per cut',
             nbins=10)
# Out:
# <div>
#
#
#             <div id="220a5793-14a4-42dc-aece-4afcec3279e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById